# %%
from Make_collected_dataset import X, Y
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import tsfel
# Out:
# (24, 500, 3)
# (24,)

# %%
activity_classes = {"WALKING":1,"WALKING_UPSTAIRS":2,"WALKING_DOWNSTAIRS":3,"SITTING":4,"STANDING":5,"LAYING":6}

# %%
cfg = tsfel.get_features_by_domain()

# %%
features = tsfel.time_series_features_extractor(cfg, X)
# Out:
# *** Feature extraction started ***
# C:\Users\vedan\AppData\Local\Temp\ipykernel_27148\2015305266.py:1: UserWarning: Using default sampling frequency set in configuration file.
#   features = tsfel.time_series_features_extractor(cfg, X)
#               <p>
#                   Progress: 100% Complete
#               <p/>
#               <progress
#                   value='24'
#                   max='24',
#                   style='width: 25%',
#               >
#                   24
#               </progress>
# *** Feature extraction finished ***

# %%
features
# Out:
#     0_Absolute energy  0_Area under the curve  0_Autocorrelation  \
# 0           2465.7580                 6.55735                2.0
# 1           1678.5701                 5.86805                2.0
# 2           1282.8568                 5.13520                2.0
# 3           1215.6256                 4.76845                2.0
# 4           1360.8524                 5.10645                2.0
# 5           1028.5090                 4.76640                2.0
# 6           1217.7520                 5.07855                2.0
# 7            955.3248                 4.66765                2.0
# 8              0.8004                 0.12330                2.0
# 9              0.4046                 0.10400                3.0
# 10             0.3718                 0.09250                3.0
# 11             0.3066                 0.08820                3.0
# 12             0.3201                 0.08095                2.0
# ...

# %%
features.shape
# Out:
# (24, 1152)

# %%
features.to_csv("X_collected_tsfel.csv",index=False)

# %%
np.savetxt('y_collected_tsfel.csv', Y, delimiter=',')
